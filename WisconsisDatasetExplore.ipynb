# %% [markdown]
# **Exploring Breast Cancer Wisconsin Dataset**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install --upgrade matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Load the Data**

# %%
# taking permission from google drive acount holder for using dataset
from google.colab import drive # permission for inserting dataset from google drive
drive.mount('/content/drive') # make drive accessible
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# reading data from google drive folder link
data = pd.read_csv('/content/drive/Shareddrives/Research_datasets/WisconsisData.csv') #inserting data from google drive

# %%
data.head() # show first five data
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail() # show last five data
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data.shape # df.shape gives the number of instances and features (i.e. rows and columns) in the data frame.
# Out:
# (569, 33)

# %%
data.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
fig = plt.figure(facecolor='w', figsize=(10, 6), dpi=600)
diagnosis_counts = data['diagnosis'].value_counts()
plt.bar(diagnosis_counts.index, diagnosis_counts.values, color=['#07BFB1', '#F30BF7'])
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Clean and prepare the data**

# %%
data.drop('id',axis=1,inplace=True)
data.drop('Unnamed: 32',axis=1,inplace=True)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data['diagnosis'] = data['diagnosis'].map({'M':1,'B':0})
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
print(data.std())
# Out:
# diagnosis                    0.483918
# radius_mean                  3.524049
# texture_mean                 4.301036
# perimeter_mean              24.298981
# area_mean                  351.914129
# smoothness_mean              0.014064
# compactness_mean             0.052813
# concavity_mean               0.079720
# concave points_mean          0.038803
# symmetry_mean                0.027414
# fractal_dimension_mean       0.007060
# radius_se                    0.277313
# texture_se                   0.551648
# perimeter_se                 2.021855
# area_se                     45.491006
# smoothness_se                0.003003
# compactness_se               0.017908
# concavity_se                 0.030186
# concave points_se            0.006170
# symmetry_se                  0.008266
# fractal_dimension_se         0.002646
# radius_worst                 4.833242
# texture_worst                6.146258
# perimeter_worst             33.602542
# area_worst                 569.356993
# ...

# %% [markdown]
# **Copy data for minMaxScalling**

# %%
df_model = data.copy()

# %% [markdown]
# **Building Model**

# %%
X=data.drop(['diagnosis'],axis=1)
y = data['diagnosis']
a = df_model.drop(['diagnosis'],axis=1)
b = df_model['diagnosis']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=40)
a_train, a_test, b_train, b_test = train_test_split(a,b,test_size=0.3,random_state=40)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %% [markdown]
# **MinMax Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()

a_train = mms.fit_transform(a_train)
a_test = mms.fit_transform(a_test)

# %% [markdown]
# **Models and finding out the Best one**

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

dtc=DecisionTreeClassifier(random_state=0)
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)
cm2

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm2, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("Decision Tree")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %% [markdown]
# TP :109 cases are correctly identified TN :54 are correctly rejected FN : 6 are incorrectly rejected and FP : 2 are incorrectly identified

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.9415204678362573

# %% [markdown]
# **Accuracy tells you how many times the ML model was correct overall. Precision is how good the model is at predicting a specific category. Recall tells you how many times the model was able to detect a specific category. The F-measure is calculated as the harmonic mean of precision and recall, giving each the same weighting**

# %%
print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       115
#            1       0.90      0.93      0.91        56
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# **Decision Tree Hyperparameter Tuning using GridSearchCV**

# %%
from scipy.stats.distributions import randint
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

params = {
    'max_depth': [5, 6, 7, 8, 9, None],
    'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'criterion': ["gini", "entropy"]
}

model=DecisionTreeClassifier(random_state=99)

dtc_hyper = GridSearchCV(model,params,cv=5)
# dtc_hyper = RandomizedSearchCV(estimator = model, param_distributions = params,
#                n_iter = 90, cv = 5, verbose=2, random_state=35, n_jobs = -1)
dtc_hyper.fit(X_train,y_train.values.ravel())

def display(results):
    print(f'Best parameters are: {results.best_params_}')
    print("\n")
    mean_score = results.cv_results_['mean_test_score']
    std_score = results.cv_results_['std_test_score']
    params = results.cv_results_['params']
    for mean,std,params in zip(mean_score,std_score,params):
        print(f'{round(mean,3)} + or -{round(std,3)} for the {params}')

# %%
dtc_hyper. best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5}

# %%
#Predict testing set
y_pred_dtc = dtc_hyper.predict(X_test)
cm3=confusion_matrix(y_test,y_pred_dtc)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm3, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("Decision Tree")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.savefig('dt_cm_dpi_600.png', dpi=600)
plt.show()

#Check performance using accuracy
print(accuracy_score(y_test, y_pred_dtc))
#Check performance using ROC
print(roc_auc_score(y_test, y_pred_dtc))
#print
print(classification_report(y_test, y_pred_dtc))
# Out:
# 0.9415204678362573
# 0.947360248447205
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96       115
#            1       0.87      0.96      0.92        56
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.95      0.94       171
# weighted avg       0.95      0.94      0.94       171

# %%
from google.colab import files

files.download('dt_cm_dpi_600.png')

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(random_state=99)
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[111,   4],
#        [  1,  55]])

# %%
accuracy_score(y_test, prediction3)
# Out:
# 0.9707602339181286

# %%
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       115
#            1       0.93      0.98      0.96        56
#
#     accuracy                           0.97       171
#    macro avg       0.96      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# **Hyper Parameters Tuning of Random Forest**

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

parameters = {
    "n_estimators":[5,10,50,100,250],
    "max_depth":[2,4,8,16,32,None],
    "max_features": ['auto', 'sqrt', 'log2']
}

# cv = GridSearchCV(rfc,parameters,cv=5)
cv = RandomizedSearchCV(estimator = rfc,

param_distributions = parameters,
               n_iter = 90, cv = 5, verbose=2, random_state=35, n_jobs = -1)
cv.fit(X_train,y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=99),
#                    n_iter=90, n_jobs=-1,
#                    param_distributions={'max_depth': [2, 4, 8, 16, 32, None],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'n_estimators': [5, 10, 50, 100, 250]},
#                    random_state=35, verbose=2)

# %%
cv. best_params_
# Out:
# {'n_estimators': 100, 'max_features': 'log2', 'max_depth': 8}

# %%
#Predict testing set
y_pred_rfc = cv.predict(X_test)
cm4=confusion_matrix(y_test,y_pred_dtc)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm4, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("Random Forest")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.savefig('rf_cm_dpi_600.png', dpi=600)
plt.show()
#Check performance using accuracy
print(accuracy_score(y_test, y_pred_rfc))
#Check performance using ROC
roc_auc_score(y_test, y_pred_rfc)
#print
print(classification_report(y_test, y_pred_rfc))
# Out:
# 0.9707602339181286
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       115
#            1       0.93      0.98      0.96        56
#
#     accuracy                           0.97       171
#    macro avg       0.96      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
from google.colab import files

files.download('rf_cm_dpi_600.png')

# %% [markdown]
# **K Nearest Neighbor (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()
model4 = knn.fit(X_train, y_train)
prediction4 = model4.predict(X_test)
confusion_matrix(y_test, prediction4)
# Out:
# array([[112,   3],
#        [  3,  53]])

# %%
accuracy_score(y_test, prediction4)
# Out:
# 0.9649122807017544

# %%
print(classification_report(y_test, prediction4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       115
#            1       0.95      0.95      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

#List Hyperparameters to tune
leaf_size = list(range(1,50))
n_neighbors = list(range(1,30))
p=[1,2]
#convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Making model
clf = GridSearchCV(knn, hyperparameters, cv=10)
best_model = clf.fit(X_train,y_train)
#Best Hyperparameters Value
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])


#Check performance using accuracy
y_pred = best_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
#Check performance using ROC
roc_auc_score(y_test, y_pred)
#print
print(classification_report(y_test, y_pred))
# Out:
# Best leaf_size: 1
# Best p: 1
# Best n_neighbors: 3
# 0.9883040935672515
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       115
#            1       0.98      0.98      0.98        56
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
#Predict testing set
cm5=confusion_matrix(y_test,y_pred)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm5, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("K-Nearest Neighbour")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.savefig('knn_cm_dpi_600.png', dpi=600)
plt.show()

# %%
from google.colab import files

files.download('knn_cm_dpi_600.png')

# %% [markdown]
# **Support Vector Machine**

# %%
from sklearn import svm

svm_clf= svm.SVC()
model5 = svm_clf.fit(X_train, y_train)
prediction5 = model5.predict(X_test)
confusion_matrix(y_test, prediction5)
# Out:
# array([[114,   1],
#        [  1,  55]])

# %%
accuracy_score(y_test, prediction5)
# Out:
# 0.9883040935672515

# %%
print(classification_report(y_test, prediction5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       115
#            1       0.98      0.98      0.98        56
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %% [markdown]
# **SVM Hyperparameter Tuning using GridSearchCV**

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.613 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.613 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.608 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.608 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.938 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.937 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.925 total time=   0.0s
# ...

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=10, gamma=0.01)

# %%
  #Predict testing set
grid_predictions = grid.predict(X_test)
cm6=confusion_matrix(y_test,grid_predictions)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm6, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("SVM")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
#Check performance using accuracy
print(accuracy_score(y_test, y_pred))
#Check performance using ROC
roc_auc_score(y_test, y_pred)
# Out:
# 0.9883040935672515
# 0.9867236024844722

# %%
from google.colab import files

files.download('dt_cm_dpi_600.png')

# %% [markdown]
# **Naive Bayes Classifier**

# %%
# training the model on training set
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
  
# making predictions on the testing set
prediction6 = gnb.predict(X_test)
  
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, prediction6)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 95.90643274853801

# %%
print(classification_report(y_test, prediction6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       115
#            1       0.93      0.95      0.94        56
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.95       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# **Naive Bayes Hyperparameter Tuning using GridSearchCV**

# %%
param_grid_nb = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

# %%
nbModel_grid = GridSearchCV(estimator=GaussianNB(), param_grid=param_grid_nb, verbose=1, cv=10, n_jobs=-1)
# nbModel_grid = RandomizedSearchCV(estimator = GaussianNB(), param_distributions = param_grid_nb, n_iter = 90, cv = 5, verbose=2, random_state=42, n_jobs = -1)
nbModel_grid.fit(X_train, y_train)
print(nbModel_grid.best_estimator_)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# GaussianNB(var_smoothing=0.01519911082952933)

# %%
y_pred = nbModel_grid.predict(X_test)
print(accuracy_score(y_test, y_pred), ": is the accuracy score")
print(confusion_matrix(y_test, y_pred), ": is the confusion matrix")
cm7=confusion_matrix(y_test,y_pred)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm7, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("Naive Bayes")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.savefig('nb_cm_dpi_600.png', dpi=600)
plt.show()
print(classification_report(y_test, y_pred), ": is the classification report")
# Out:
# 0.9590643274853801 : is the accuracy score
# [[111   4]
#  [  3  53]] : is the confusion matrix
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       115
#            1       0.93      0.95      0.94        56
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.95       171
# weighted avg       0.96      0.96      0.96       171
#  : is the classification report

# %%
from google.colab import files

files.download('nb_cm_dpi_600.png')

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
  
# making predictions on the testing set
prediction7 = lr.predict(X_test)
  
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Logistic Regression model accuracy(in %):", metrics.accuracy_score(y_test, prediction7)*100)
print(classification_report(y_test, prediction7))
# Out:
# Logistic Regression model accuracy(in %): 96.49122807017544
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       115
#            1       0.93      0.96      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.97      0.96      0.97       171

# %% [markdown]
# **Logistic Regression with hyperparameter tuning**

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

clf = GridSearchCV(lr, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)
best_lr = clf.fit(X_train, y_train)
print(best_lr.best_estimator_)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# LogisticRegression(C=1.623776739188721, penalty='l1', solver='saga')
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 4800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
# ...

# %%
y_pred = best_lr.predict(X_test)
print(accuracy_score(y_test, y_pred), ": is the accuracy score")
print(confusion_matrix(y_test, y_pred), ": is the confusion matrix")
cm9=confusion_matrix(y_test,y_pred)

sns.set(font_scale=1.4) # set font size
sns.heatmap(cm9, annot=True, annot_kws={"size": 10}, cmap='Blues', cbar=False, fmt='g')

plt.suptitle("Logistic Regression")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.savefig('lr_cm_dpi_600.png', dpi=600)
plt.show()
print(classification_report(y_test, y_pred), ": is the classification report")
# Out:
# 0.9707602339181286 : is the accuracy score
# [[112   3]
#  [  2  54]] : is the confusion matrix
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       115
#            1       0.95      0.96      0.96        56
#
#     accuracy                           0.97       171
#    macro avg       0.96      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171
#  : is the classification report

# %%
from google.colab import files

files.download('lr_cm_dpi_600.png')

# %% [markdown]
# **Graph comparison**

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6), dpi=600)
ax = fig.add_axes([0,0,1, 1])
names = ['DT', 'DT_tuned','RF', 'RF_tuned','KNN', 'KNN_tuned', 'NB', 'NB_tuned', 'LR', 'LR_tuned']
# accuracy = [0.9415204678362573, 0.9298245614035088, 0.9707602339181286, 0.9649122807017544, 0.9649122807017544, 0.9883040935672515, 0.9883040935672515, 0.9883040935672515, 0.9590643274853801, 0.9590643274853801 ]
accuracy = [93.56, 94.15, 97.08, 97.08, 96.49, 98.83, 95.91, 95.91, 96.49, 97.08]
# color = []
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.bar_label(ax.bar(names[0],accuracy[0],color='#f0be1a', label="Without Tuning"))
ax.bar_label(ax.bar(names[1],accuracy[1],color='#1af077', label="With Tuning"))
ax.bar_label(ax.bar(names[2],accuracy[2],color='#f0be1a',))
ax.bar_label(ax.bar(names[3],accuracy[3],color='#1af077'))
ax.bar_label(ax.bar(names[4],accuracy[4],color='#f0be1a'))
ax.bar_label(ax.bar(names[5],accuracy[5],color='#1af077'))
ax.bar_label(ax.bar(names[6],accuracy[6],color='#f0be1a'))
ax.bar_label(ax.bar(names[7],accuracy[7],color='#1af077'))
ax.bar_label(ax.bar(names[8],accuracy[8],color='#f0be1a'))
ax.bar_label(ax.bar(names[9],accuracy[9],color='#1af077'))
# ax.bar_label(ax.bar(names[10],accuracy[10],color='#f0be1a'))
# ax.bar_label(ax.bar(names[11],accuracy[11],color='#1af077'))
ax.legend(bbox_to_anchor=(0.7,0.6),loc="lower left", borderaxespad=0.)
plt.xlabel("Algorithm name")
plt.ylabel("Accuracy")
plt.ylim(bottom=50, top=100)
plt.show()
# fname = "comparison.png"
# plt.savefig(fname,transparent=True, dpi=100)

# %%
fig = plt.figure(figsize=(10, 6), dpi=600)
ax = fig.add_axes([0,0,1, 1])
names = ["A", "B", 'C', "D", "E", "F", "G"]
# accuracy = [0.9415204678362573, 0.9298245614035088, 0.9707602339181286, 0.9649122807017544, 0.9649122807017544, 0.9883040935672515, 0.9883040935672515, 0.9883040935672515, 0.9590643274853801, 0.9590643274853801 ]
accuracy = [98.83, 97.35, 96.8, 96, 95.95, 95.29, 95.9578]
# color = []
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.bar_label(ax.bar(names[0],accuracy[0],color='#1af077', label="A = Our Paper"))
ax.bar_label(ax.bar(names[1],accuracy[1],color='#1af077', label="B = Rasool et al. [16], 2022"))
ax.bar_label(ax.bar(names[2],accuracy[2],color='#1af077', label="C = Roy et al. [2], 2021"))
ax.bar_label(ax.bar(names[3],accuracy[3],color='#1af077', label="D = Roy et al. [11], 2020"))
ax.bar_label(ax.bar(names[4],accuracy[4],color='#1af077', label="E = Rajaguru et al. [20], 2019"))
ax.bar_label(ax.bar(names[5],accuracy[5],color='#1af077', label="F = Gupta et al. [27], 2018"))
ax.bar_label(ax.bar(names[6],accuracy[6],color='#1af077', label="G = Salama et al. [28], 2012"))

ax.legend(bbox_to_anchor=(0.5,0.5),loc="lower left", borderaxespad=0.)
plt.xlabel("Study using WDBC")
plt.ylabel("Accuracy of KNN Classifier")
plt.ylim(bottom=50, top=100)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6), dpi=600)
ax = fig.add_axes([0,0,1, 1])
names = ["A", "B", 'C', "D", "E"]
# accuracy = [0.9415204678362573, 0.9298245614035088, 0.9707602339181286, 0.9649122807017544, 0.9649122807017544, 0.9883040935672515, 0.9883040935672515, 0.9883040935672515, 0.9590643274853801, 0.9590643274853801 ]
accuracy = [98.83, 97.35, 96.8, 96, 95.95]
# color = []
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.bar_label(ax.bar(names[0],accuracy[0],color='#1af077', label="A = Our Paper"))
ax.bar_label(ax.bar(names[1],accuracy[1],color='#1af077', label="B = Rasool et al. [21], 2022"))
ax.bar_label(ax.bar(names[2],accuracy[2],color='#1af077', label="C = Roy et al. [2], 2021"))
ax.bar_label(ax.bar(names[3],accuracy[3],color='#1af077', label="D = Roy et al. [15], 2020"))
ax.bar_label(ax.bar(names[4],accuracy[4],color='#1af077', label="E = Rajaguru et al. [28], 2019"))
# ax.bar_label(ax.bar(names[5],accuracy[5],color='#1af077', label="F = Amrane et al. [10], 2018"))

ax.legend(bbox_to_anchor=(0.5,0.5),loc="lower left", borderaxespad=0.)
plt.xlabel("Study using WDBC")
plt.ylabel("Accuracy of KNN Classifier")
plt.ylim(bottom=50, top=100)
plt.show()

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# Generate predictions on the test set
classifiers = {"Decision Tree": dtc_hyper, "Random Forest": cv, "KNN": best_model, "Naive Bayes": nbModel_grid, "Logistic Regression": best_lr}

# calculate ROC curve and AUC for each model
plt.figure(figsize=(10, 6), dpi=600)
# ax = plt.gca()
# ax.set_facecolor('#E8E9EB')
for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_score = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=name + ' (AUC = %0.2f)' % roc_auc)

# plot ROC curve for all models
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlim([-0.02, 1.02])
plt.ylim([-0.02, 1.02])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC & ROC Curve After Tuning')
plt.legend(loc="lower right")
plt.show()
# Out:
# <ipython-input-89-21328dbfb351>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 4800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# plt.style.use('seaborn')

# Generate predictions on the test set
classifiers = {"Decision Tree": dtc_hyper, "Random Forest": cv, "KNN": best_model, "Naive Bayes": nbModel_grid, "Logistic Regression": best_lr}

# compute confusion matrix for each classifier
conf_matrices = []
for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    conf_matrices.append(confusion_matrix(y_test, y_pred))

# plot confusion matrices
fig, axes = plt.subplots(2, 3, figsize=(8, 8))
fig.suptitle("Confusion Matrices")

for i, (name, _) in enumerate(classifiers.items()):
    row = i // 3
    col = i % 3
    ax = axes[row, col]
    ax.imshow(conf_matrices[i], cmap=plt.cm.Blues)
    ax.set_xticks(np.arange(2))
    ax.set_yticks(np.arange(2))
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    ax.set_title(name)
    for j in range(2):
        for k in range(2):
            ax.text(k, j, str(conf_matrices[i][j, k]), ha="center", va="center", color="white" if conf_matrices[i][j, k] > conf_matrices[i].sum() / 2 else "black")

plt.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 4800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content
